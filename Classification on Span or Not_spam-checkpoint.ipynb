# %% [markdown]
# Introduction:
# The proliferation of email as a primary communication tool has brought about significant convenience and challenges, such as the issue of spam emails. Spam emails not only clutter inboxes but also pose security risks by potentially containing malicious content.
# Therefore, effectively classifying emails as spam or non-spam is critical for enhancing user experience and maintaining cybersecurity. This notebook aims to classify emails into spam and non-spam categories using data analysis and machine learning technique.

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# DATA READING..

# %%
df=pd.read_csv("spam_ham.csv", index_col=0)
df
# Out:
#             the  to  ect  and  for  of    a  you  hou  in  ...  connevey  jay  \
# Email No.                                                  ...
# Email 1       0   0    1    0    0   0    2    0    0   0  ...         0    0
# Email 2       8  13   24    6    6   2  102    1   27  18  ...         0    0
# Email 3       0   0    1    0    0   0    8    0    0   4  ...         0    0
# Email 4       0   5   22    0    5   1   51    2   10   1  ...         0    0
# Email 5       7   6   17    1    5   2   57    0    9   3  ...         0    0
# ...         ...  ..  ...  ...  ...  ..  ...  ...  ...  ..  ...       ...  ...
# Email 5168    2   2    2    3    0   0   32    0    0   5  ...         0    0
# Email 5169   35  27   11    2    6   5  151    4    3  23  ...         0    0
# Email 5170    0   0    1    1    0   0   11    0    0   1  ...         0    0
# Email 5171    2   7    1    0    2   1   28    2    0   8  ...         0    0
# ...

# %% [markdown]
# Preprocession Data..

# %%
df.head(10)
# Out:
#            the  to  ect  and  for  of    a  you  hou  in  ...  connevey  jay  \
# Email No.                                                 ...
# Email 1      0   0    1    0    0   0    2    0    0   0  ...         0    0
# Email 2      8  13   24    6    6   2  102    1   27  18  ...         0    0
# Email 3      0   0    1    0    0   0    8    0    0   4  ...         0    0
# Email 4      0   5   22    0    5   1   51    2   10   1  ...         0    0
# Email 5      7   6   17    1    5   2   57    0    9   3  ...         0    0
# Email 6      4   5    1    4    2   3   45    1    0  16  ...         0    0
# Email 7      5   3    1    3    2   1   37    0    0   9  ...         0    0
# Email 8      0   2    2    3    1   2   21    6    0   2  ...         0    0
# Email 9      2   2    3    0    0   1   18    0    0   3  ...         0    0
# Email 10     4   4   35    0    1   0   49    1   16   9  ...         0    0
#
# ...

# %%
df.tail(10)
# Out:
#             the  to  ect  and  for  of    a  you  hou  in  ...  connevey  jay  \
# Email No.                                                  ...
# Email 5163    2   3    1    2    1   2   32    0    0   7  ...         0    0
# Email 5164    0   0    1    0    0   0    1    0    0   0  ...         0    0
# Email 5165   21  18    3    1    6   4  106    1    2  18  ...         0    0
# Email 5166    1   0    1    0    3   1   12    1    0   2  ...         0    0
# Email 5167    1   0    1    1    0   0    4    0    0   0  ...         0    0
# Email 5168    2   2    2    3    0   0   32    0    0   5  ...         0    0
# Email 5169   35  27   11    2    6   5  151    4    3  23  ...         0    0
# Email 5170    0   0    1    1    0   0   11    0    0   1  ...         0    0
# Email 5171    2   7    1    0    2   1   28    2    0   8  ...         0    0
# Email 5172   22  24    5    1    6   5  148    8    2  23  ...         0    0
#
# ...

# %%
df.shape
# Out:
# (5172, 3001)

# %%
df.columns
# Out:
# Index(['the', 'to', 'ect', 'and', 'for', 'of', 'a', 'you', 'hou', 'in',
#        ...
#        'connevey', 'jay', 'valued', 'lay', 'infrastructure', 'military',
#        'allowing', 'ff', 'dry', 'Prediction'],
#       dtype='object', length=3001)

# %%
#For visualizing all Columns Name:
all_columns = df.columns.tolist()
#all_columns
print(all_columns)
# Out:
# ['the', 'to', 'ect', 'and', 'for', 'of', 'a', 'you', 'hou', 'in', 'on', 'is', 'this', 'enron', 'i', 'be', 'that', 'will', 'have', 'with', 'your', 'at', 'we', 's', 'are', 'it', 'by', 'com', 'as', 'from', 'gas', 'or', 'not', 'me', 'deal', 'if', 'meter', 'hpl', 'please', 're', 'e', 'any', 'our', 'corp', 'can', 'd', 'all', 'has', 'was', 'know', 'need', 'an', 'forwarded', 'new', 't', 'may', 'up', 'j', 'mmbtu', 'should', 'do', 'am', 'get', 'out', 'see', 'no', 'there', 'price', 'daren', 'but', 'been', 'company', 'l', 'these', 'let', 'so', 'would', 'm', 'into', 'xls', 'farmer', 'attached', 'us', 'information', 'they', 'message', 'day', 'time', 'my', 'one', 'what', 'only', 'http', 'th', 'volume', 'mail', 'contract', 'which', 'month', 'more', 'robert', 'sitara', 'about', 'texas', 'nom', 'energy', 'pec', 'questions', 'www', 'deals', 'volumes', 'pm', 'ena', 'now', 'their', 'file', 'some', 'email', 'just', 'also', 'call', 'change', 'other', 'here', 'like', 'b', 'flow', 'net', 'following', 'p', 'p
# ...

# %%
df.dtypes
# Out:
# the           int64
# to            int64
# ect           int64
# and           int64
# for           int64
#               ...
# military      int64
# allowing      int64
# ff            int64
# dry           int64
# Prediction    int64
# Length: 3001, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5172 entries, Email 1 to Email 5172
# Columns: 3001 entries, the to Prediction
# dtypes: int64(3001)
# memory usage: 118.5+ MB

# %%
df.describe()
# Out:
#                the           to          ect          and          for  \
# count  5172.000000  5172.000000  5172.000000  5172.000000  5172.000000
# mean      6.640565     6.188128     5.143852     3.075599     3.124710
# std      11.745009     9.534576    14.101142     6.045970     4.680522
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# 25%       0.000000     1.000000     1.000000     0.000000     1.000000
# 50%       3.000000     3.000000     1.000000     1.000000     2.000000
# 75%       8.000000     7.000000     4.000000     3.000000     4.000000
# max     210.000000   132.000000   344.000000    89.000000    47.000000
#
#                 of            a          you          hou           in  ...  \
# count  5172.000000  5172.000000  5172.000000  5172.000000  5172.000000  ...
# mean      2.627030    55.517401     2.466551     2.024362    10.600155  ...
# std       6.229845    87.574172     4.314444     6.967878    19.281892  ...
# ...

# %%
df.isnull().sum()
# Out:
# the           0
# to            0
# ect           0
# and           0
# for           0
#              ..
# military      0
# allowing      0
# ff            0
# dry           0
# Prediction    0
# Length: 3001, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df['Prediction'].value_counts()
# Out:
# 0    3672
# 1    1500
# Name: Prediction, dtype: int64

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='Prediction', data=df)
plt.xticks([0,1],['Not Spam','Spam'])
plt.show()

# %%
num_columns = 12
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(12, 12))
axes = axes.flatten()
# Filter data based on spam and non-spam
spam_df = df[df['Prediction'] == 1]
non_spam_df = df[df['Prediction'] == 0]
# Loop through the first 12 columns and create distribution plots for spam and non-spam
for i, col in enumerate(df.columns[:num_columns]):
    # Plot for non-spam emails
    sns.histplot(non_spam_df[col], ax=axes[i], kde=True, color='blue', label='Non-Spam')
    # Plot for spam emails
    sns.histplot(spam_df[col], ax=axes[i], kde=True, color='red', label='Spam')
    axes[i].set_title(col)
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
"""correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()"""
# Out:
# "correlation_matrix = df.corr()\nplt.figure(figsize=(10, 8))\nsns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')\nplt.show()"

# %% [markdown]
# SPLIT DATA into Traget and Features.

# %%
x=df.drop('Prediction', axis=1)
x
# Out:
#             the  to  ect  and  for  of    a  you  hou  in  ...  enhancements  \
# Email No.                                                  ...
# Email 1       0   0    1    0    0   0    2    0    0   0  ...             0
# Email 2       8  13   24    6    6   2  102    1   27  18  ...             0
# Email 3       0   0    1    0    0   0    8    0    0   4  ...             0
# Email 4       0   5   22    0    5   1   51    2   10   1  ...             0
# Email 5       7   6   17    1    5   2   57    0    9   3  ...             0
# ...         ...  ..  ...  ...  ...  ..  ...  ...  ...  ..  ...           ...
# Email 5168    2   2    2    3    0   0   32    0    0   5  ...             0
# Email 5169   35  27   11    2    6   5  151    4    3  23  ...             0
# Email 5170    0   0    1    1    0   0   11    0    0   1  ...             0
# Email 5171    2   7    1    0    2   1   28    2    0   8  ...             0
# ...

# %%
y=df['Prediction']
y
# Out:
# Email No.
# Email 1       0
# Email 2       0
# Email 3       0
# Email 4       0
# Email 5       0
#              ..
# Email 5168    0
# Email 5169    0
# Email 5170    1
# Email 5171    1
# Email 5172    0
# Name: Prediction, Length: 5172, dtype: int64

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2, random_state=42)
print(f"Training Features Shape: {x_train.shape}")
print(f"Training Labels Shape: {y_train.shape}")
print(f"Test Features Shape: {x_test.shape}")
print(f"Test Labels Shape: {y_test.shape}")
# Out:
# Training Features Shape: (4137, 3000)
# Training Labels Shape: (4137,)
# Test Features Shape: (1035, 3000)
# Test Labels Shape: (1035,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)  # Fit the scaler on training data and transform it
x_test = scaler.transform(x_test)

# %% [markdown]
# ### LOGISTIC REGRESSION..

# %%
from sklearn.linear_model import LogisticRegression
LR_model = LogisticRegression(random_state=42, max_iter=3000)
LR_model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=3000, random_state=42)

# %%
y_pred = LR_model.predict(x_test)
y_pred
# Out:
# array([0, 0, 1, ..., 0, 1, 0], dtype=int64)

# %%
accuracy = accuracy_score(y_pred, y_test)
print(f"Accuracy Of Logistic Regression: {accuracy}")
print("Classification Report :\n",classification_report(y_pred, y_test))
print("Confusion Matrix :\n",confusion_matrix(y_pred, y_test))
# Out:
# Accuracy Of Logistic Regression: 0.9652173913043478
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       713
#            1       0.98      0.90      0.94       322
#
#     accuracy                           0.97      1035
#    macro avg       0.97      0.95      0.96      1035
# weighted avg       0.97      0.97      0.96      1035
#
# Confusion Matrix :
#  [[708   5]
#  [ 31 291]]

# %% [markdown]
# ### NOW DECISION TREE..

# %%
from sklearn.tree import DecisionTreeClassifier
Dtree_cls = DecisionTreeClassifier(random_state=42)
Dtree_cls.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred=Dtree_cls.predict(x_test)
y_pred
# Out:
# array([0, 0, 1, ..., 0, 1, 0], dtype=int64)

# %%
D_accuracy = accuracy_score(y_pred, y_test)
print(f"Accuracy Of Decision Tree: {D_accuracy}")
print("Classification Report :\n",classification_report(y_pred, y_test))
print("Confusion Matrix :\n",confusion_matrix(y_pred, y_test))
# Out:
# Accuracy Of Decision Tree: 0.923671497584541
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       738
#            1       0.87      0.87      0.87       297
#
#     accuracy                           0.92      1035
#    macro avg       0.91      0.91      0.91      1035
# weighted avg       0.92      0.92      0.92      1035
#
# Confusion Matrix :
#  [[699  39]
#  [ 40 257]]

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100, max_depth=15, random_state=42)
random_forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=15, random_state=42)

# %%
y_pred=random_forest.predict(x_test)
y_pred
# Out:
# array([0, 0, 1, ..., 0, 1, 0], dtype=int64)

# %%
R_accuracy = accuracy_score(y_pred, y_test)
print(f"Accuracy Of Decision Tree: {R_accuracy}")
print("Classification Report :\n",classification_report(y_pred, y_test))
print("Confusion Matrix :\n",confusion_matrix(y_pred, y_test))
# Out:
# Accuracy Of Decision Tree: 0.9710144927536232
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       741
#            1       0.95      0.95      0.95       294
#
#     accuracy                           0.97      1035
#    macro avg       0.96      0.97      0.96      1035
# weighted avg       0.97      0.97      0.97      1035
#
# Confusion Matrix :
#  [[725  16]
#  [ 14 280]]

# %% [markdown]
# ### NOW Support Vector Machine..

# %%
from sklearn.svm import SVC
svm = SVC(kernel='linear')
svm.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=svm.predict(x_test)
y_pred
# Out:
# array([0, 0, 1, ..., 0, 1, 0], dtype=int64)

# %%
S_accuracy = accuracy_score(y_pred, y_test)
print(f"Accuracy Of SVM: {S_accuracy}")
print("Classification Report :\n",classification_report(y_pred, y_test))
print("Confusion Matrix :\n",confusion_matrix(y_pred, y_test))
# Out:
# Accuracy Of SVM: 0.9468599033816425
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96       730
#            1       0.92      0.90      0.91       305
#
#     accuracy                           0.95      1035
#    macro avg       0.94      0.93      0.94      1035
# weighted avg       0.95      0.95      0.95      1035
#
# Confusion Matrix :
#  [[707  23]
#  [ 32 273]]

# %% [markdown]
# ### GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gbc.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred = gbc.predict(x_test)

# %%
g_accuracy = accuracy_score(y_pred, y_test)
print(f"Accuracy Of Gradient Boosting: {g_accuracy}")
print("Classification Report :\n",classification_report(y_pred, y_test))
print("Confusion Matrix :\n",confusion_matrix(y_pred, y_test))
# Out:
# Accuracy Of Gradient Boosting: 0.9719806763285024
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       734
#            1       0.96      0.94      0.95       301
#
#     accuracy                           0.97      1035
#    macro avg       0.97      0.96      0.97      1035
# weighted avg       0.97      0.97      0.97      1035
#
# Confusion Matrix :
#  [[722  12]
#  [ 17 284]]

# %% [markdown]
# ### KNN Classifier..

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(x_test)

# %%
K_accuracy = accuracy_score(y_pred, y_test)
print(f"Accuracy Of KNN Classifier: {K_accuracy}")
print("Classification Report:\n",classification_report(y_pred, y_test))
print("Confusion Matrix:\n",confusion_matrix(y_pred, y_test))
# Out:
# Accuracy Of KNN Classifier: 0.8657004830917875
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90       638
#            1       0.94      0.70      0.80       397
#
#     accuracy                           0.87      1035
#    macro avg       0.89      0.83      0.85      1035
# weighted avg       0.88      0.87      0.86      1035
#
# Confusion Matrix:
#  [[619  19]
#  [120 277]]

# %% [markdown]
# ### SUMMARY:

# %% [markdown]
#     This project focuses on classifying emails as spam or non-spam using machine learning techniques. The goal is to improve user experience and enhance cybersecurity by filtering out spam emails. The notebook covers data preprocessing, exploratory data analysis (EDA), and visualization techniques before implementing various machine learning algorithms.
#
# Multiple models were tested, including Logistic Regression, Decision Tree, SVM, Gradient Boosting, and K-Nearest Neighbors (KNN). Logistic Regression achieved an accuracy of 96.52%, while Gradient Boosting slightly outperformed with 97.19%. SVM also performed well with an accuracy of 94.69%, while KNN lagged behind at 86.57%. Overall, Gradient Boosting was the most accurate model, followed closely by Logistic Regression.
#
# Key metrics from classification reports (precision, recall, and F1-score) indicate that all models performed better on non-spam emails (class 0), while spam detection (class 1) showed some variation. Confusion matrices further highlight that models like Logistic Regression and Gradient Boosting had fewer false positives and negatives compared to others.
